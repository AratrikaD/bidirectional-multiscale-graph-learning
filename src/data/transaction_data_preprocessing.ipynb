# %% [markdown]
# # Clean and Preprocess Transaction Data

# %%
import pandas as pd

# %%
df_total = pd.read_parquet('../../housing-data/original/df_total_ml.parquet')
df_spatial = pd.read_parquet('../../housing-data/original/ml_dataset_spatial.parquet')

# %%
extra_total = df_total.columns.difference(df_spatial.columns)
df_combined = df_spatial.merge(df_total[extra_total.append(pd.Index(["TRANSID"]))], on="TRANSID", how='inner')

# %%
# Repeated column
df_combined.drop(["POSTCODE4"], inplace=True, axis=1)

# %%
# Define Transaction Features

transaction_features = ['TRANSID', 'DATUM', 'KOOPSOM', 'WONINGTYPE', 'SOC', 'CALCOPP', 'KAVOPP',
       'BOUWJAAR', 'PROVINCIECODE','COROPPLUSCODE', 'GEMEENTECODE', 'WIJKCODE', 'BUURTCODE',
       'POSTCODE', 'LAT', 'LON', 'BESTEMMING', 'DUMMY_BERGING',
       'DUMMY_GARAGE', 'DUMMY_MONUMENT', 'FOTOWIJZER_TYPE']

# %%
# Drop all other neighborhood Features
df_combined = df_combined[transaction_features]
df_combined
# Out:
#          TRANSID       DATUM  KOOPSOM WONINGTYPE   SOC  CALCOPP  KAVOPP  \
# 0        8324024   13/3/2023   378000          T  1131      124     119
# 1        4695633    1/6/2016   257000          T  1131      145     208
# 2        6267016  16/11/2020   397500          T  1131      140     130
# 3        6428993    1/2/2021  1100000          T  1136      261     162
# 4        5382171   4/12/2018   180000          A  1181       50       0
# ...          ...         ...      ...        ...   ...      ...     ...
# 1613935  4527050    2/9/2015   196000          T  1131      125     155
# 1613936  8518792  27/11/2023   359037          T  1138      123      98
# 1613937  6068581   16/6/2020   246000          A  1184       93       0
# 1613938  4943077    5/5/2017   350000          V  1111      165     367
# 1613939  5351086  30/11/2018   315000          V  1111      152     458
#
#          BOUWJAAR  PROVINCIECODE  COROPPLUSCODE  ...  WIJKCODE   BUURTCODE  \
# 0            1976             28           3002  ...  WK197804  BU19780402
# 1            2000             27           2000  ...  WK037507  BU03750702
# 2            2014             25           1500  ...  WK026809  BU02680970
# 3            1912             28           2601  ...  WK051809  BU05180907
# 4            1974             26           1701  ...  WK073601  BU07360102
# ...           ...            ...            ...  ...       ...         ...
# 1613935      1975             26           1702  ...  WK034206  BU03420601
# 1613936      1970             25           1300  ...  WK022803  BU02280301
# 1613937      2001             26           1702  ...  WK030724  BU03072403
# 1613938      1935             28           3002  ...  WK192708  BU19270801
# 1613939      1990             25           1500  ...  WK194508  BU19450800
#
#         POSTCODE        LAT       LON  BESTEMMING DUMMY_BERGING  DUMMY_GARAGE  \
# 0         3381CE  51.850627  4.893862   permanent             1             0
# 1         1945RW  52.492774  4.660815   permanent             1             0
# 2         6663JD  51.875469  5.868624   permanent             1             0
# 3         2582JB  52.091945  4.272226   permanent             1             0
# 4         3641MC  52.213655  4.862490   permanent             1             0
# ...          ...        ...       ...         ...           ...           ...
# 1613935   3766BB  52.167385  5.285358   permanent             1             0
# 1613936   6714MA  52.046115  5.638586   permanent             0             1
# 1613937   3824VS  52.199698  5.369747   permanent             1             0
# 1613938   2964GB  51.940161  4.853196   permanent             1             0
# 1613939   6578BK  51.841510  5.995801   permanent             0             1
#
#          DUMMY_MONUMENT  FOTOWIJZER_TYPE
# 0                     0                6
# 1                     0                6
# 2                     0                6
# 3                     0                6
# 4                     0                9
# ...                 ...              ...
# 1613935               0                6
# 1613936               0                6
# 1613937               0               10
# 1613938               0                1
# 1613939               0                1
#
# [1613940 rows x 21 columns]

# %% [markdown]
# ## Handle NaNs

# %%
nan_percentages = df_combined.isna().mean()*100
nan_percentages
# Out:
# TRANSID            0.000000
# DATUM              0.000000
# KOOPSOM            0.000000
# WONINGTYPE         0.000000
# SOC                0.000000
# CALCOPP            0.000000
# KAVOPP             0.000000
# BOUWJAAR           0.000000
# PROVINCIECODE      0.000000
# COROPPLUSCODE      0.000000
# GEMEENTECODE       0.024226
# WIJKCODE           0.024226
# BUURTCODE          0.024226
# POSTCODE           0.024226
# LAT                0.457266
# LON                0.457266
# BESTEMMING         0.000000
# DUMMY_BERGING      0.000000
# DUMMY_GARAGE       0.000000
# DUMMY_MONUMENT     0.000000
# FOTOWIJZER_TYPE    0.000000
# dtype: float64

# %%
# Drop rows where Buurtcode is NaN
df_combined.dropna(subset=["BUURTCODE"], inplace=True)
nan_percentages = df_combined.isna().mean()*100
nan_percentages
# Out:
# TRANSID            0.000000
# DATUM              0.000000
# KOOPSOM            0.000000
# WONINGTYPE         0.000000
# SOC                0.000000
# CALCOPP            0.000000
# KAVOPP             0.000000
# BOUWJAAR           0.000000
# PROVINCIECODE      0.000000
# COROPPLUSCODE      0.000000
# GEMEENTECODE       0.000000
# WIJKCODE           0.000000
# BUURTCODE          0.000000
# POSTCODE           0.000000
# LAT                0.442751
# LON                0.442751
# BESTEMMING         0.000000
# DUMMY_BERGING      0.000000
# DUMMY_GARAGE       0.000000
# DUMMY_MONUMENT     0.000000
# FOTOWIJZER_TYPE    0.000000
# dtype: float64

# %%
# Drop rows where LAT is NaN
df_combined.dropna(subset=["LAT"], inplace=True)
nan_percentages = df_combined.isna().mean()*100
nan_percentages = nan_percentages[nan_percentages>0]
nan_percentages
# Out:
# Series([], dtype: float64)

# %% [markdown]
# ## Log Transform Target

# %%
import numpy as np
df_combined["LOG_KOOPSOM"] = np.log(df_combined["KOOPSOM"])

# %% [markdown]
# ## Split Date into Year and Month

# %%
df_combined["DATUM"] = pd.to_datetime(df_combined["DATUM"])
# Out:
# C:\Users\AratrikaD\AppData\Local\Temp\ipykernel_364\3484397489.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df_combined["DATUM"] = pd.to_datetime(df_combined["DATUM"])

# %%
df_combined.drop(["KOOPSOM"], axis=1, inplace=True)

# %% [markdown]
# ## Remove other location features apart from BUURTCODE

# %%
df_combined.drop([ 'WIJKCODE', 'POSTCODE'], axis=1, inplace=True)
# df_rotterdam.drop([ 'WIJKCODE', 'POSTCODE'], axis=1, inplace=True)

# %% [markdown]
# ## Encode Categorical Columns

# %%
from sklearn.preprocessing import OrdinalEncoder
enc = OrdinalEncoder()
cat_cols = ['WONINGTYPE','BESTEMMING']
df_combined[cat_cols] = enc.fit_transform(df_combined[cat_cols])
enc.categories_
# Out:
# [array(['A', 'H', 'K', 'T', 'V'], dtype=object),
#  array(['doelgroep', 'permanent', 'recreatief'], dtype=object)]

# %% [markdown]
# ## Create Train-Test Splits

# %%
df_combined.dtypes
# Out:
# TRANSID                     int64
# DATUM              datetime64[ns]
# WONINGTYPE                float64
# SOC                         int64
# CALCOPP                     int64
# KAVOPP                      int64
# BOUWJAAR                    int64
# PROVINCIECODE               int64
# COROPPLUSCODE               int64
# GEMEENTECODE               object
# BUURTCODE                  object
# LAT                       float64
# LON                       float64
# BESTEMMING                float64
# DUMMY_BERGING               int64
# DUMMY_GARAGE                int64
# DUMMY_MONUMENT              int64
# FOTOWIJZER_TYPE             int64
# LOG_KOOPSOM               float64
# dtype: object

# %% [markdown]
# ## Save Files

# %%
df_combined.to_csv("../../housing-data/transaction_data.csv", index=False)

# df_rotterdam.to_csv("../../housing-data/rotterdam_transaction_data.csv", index=False)

# %%
df_combined = pd.read_csv("../../housing-data/transaction_data.csv")


df_combined
# Out:
#          TRANSID       DATUM  ...  FOTOWIJZER_TYPE  LOG_KOOPSOM
# 0        8324024  2023-03-13  ...                6    12.842649
# 1        4695633  2016-06-01  ...                6    12.456831
# 2        6267016  2020-11-16  ...                6    12.892950
# 3        6428993  2021-02-01  ...                6    13.910821
# 4        5382171  2018-12-04  ...                9    12.100712
# ...          ...         ...  ...              ...          ...
# 1606347  4527050  2015-09-02  ...                6    12.185870
# 1606348  8518792  2023-11-27  ...                6    12.791181
# 1606349  6068581  2020-06-16  ...               10    12.413087
# 1606350  4943077  2017-05-05  ...                1    12.765688
# 1606351  5351086  2018-11-30  ...                1    12.660328
#
# [1606352 rows x 19 columns]

# %%
adj_2023 = pd.read_csv("../../housing-data/buurt_adj_2023.csv",index_col=0)
adj_2023

# %%
set(df_combined["BUURTCODE"]).difference(set(adj_2023.columns.values))

# %% [markdown]
# ## Extract COROP-plus region of Rotterdam (CP:2910)

# %%
df_rotterdam = df_combined[df_combined["COROPPLUSCODE"] =="CP2910"]
df_rotterdam
# Out:
#          TRANSID       DATUM  ...  FOTOWIJZER_TYPE  LOG_KOOPSOM
# 34       7537440  2021-11-29  ...                6    12.608199
# 41       7308578  2021-09-10  ...                2    13.270783
# 47       4689877  2016-06-15  ...                6    12.301383
# 54       5421309  2019-02-01  ...                1    13.011432
# 55       6215385  2020-10-29  ...                6    12.528156
# ...          ...         ...  ...              ...          ...
# 1606291  5490122  2019-05-08  ...                9    12.107357
# 1606293  5022491  2017-08-31  ...                1    13.226904
# 1606296  5014000  2017-08-01  ...                4    12.122691
# 1606320  4641789  2016-03-02  ...                2    12.100712
# 1606323  5070150  2017-10-23  ...               14    11.790557
#
# [108999 rows x 19 columns]

# %%
import duckdb as db


gemeente_rotterdam = list(db.query("""select coroppluscode, gemeentecode from df_rotterdam group by coroppluscode, gemeentecode """).df()["GEMEENTECODE"].values)

# %%
gemeente_rotterdam
# Out:
# ['GM1930',
#  'GM0502',
#  'GM0622',
#  'GM0597',
#  'GM0556',
#  'GM0489',
#  'GM0606',
#  'GM1621',
#  'GM1992',
#  'GM0613',
#  'GM0542',
#  'GM0599']

# %%
import geopandas as gpd
import libpysal as lp

map_2023_path = "../../housing-data/cbsgebiedsindelingen2016-2025/cbsgebiedsindelingen2023.gpkg"


def read_file(file_path, layer="buurt_gegeneraliseerd"):
    gdf = gpd.read_file(file_path, layer=layer)
    #gdf = gdf[gdf['indelingswijziging_wijken_en_buurten'] > 0] -- Wel of niet???
    gdf_neighbors = lp.weights.Queen.from_dataframe(gdf, use_index=False)
    gdf_neighbors.to_sparse()
    codes = gdf.iloc[:, :1].to_numpy().flatten()
    adj_df = pd.DataFrame.sparse.from_spmatrix(
        gdf_neighbors.to_sparse(), index=codes, columns=codes
    )
    return adj_df, gdf

adj_df_2023, gdf_2023 = read_file(map_2023_path)
# Out:
# c:\Users\AratrikaD\gnns-for-property-valuation\.venv\lib\site-packages\libpysal\weights\contiguity.py:347: UserWarning: The weights matrix is not fully connected:
#  There are 10 disconnected components.
#  There are 4 islands with ids: 3025, 10085, 10252, 10810.
#   W.__init__(self, neighbors, ids=ids, **kw)

# %%
buurten_rotterdam = list(gdf_2023[gdf_2023["gm_code"].isin(gemeente_rotterdam)]["statcode"].values)
print(buurten_rotterdam)
# gdf_2023[gdf_2023["gm_code"].isin(gemeente_rotterdam)]
# gdf_2023[gdf_2023["statcode"] == "BU19920505"]
# Out:
# ['BU04890101', 'BU04890102', 'BU04890103', 'BU04890204', 'BU04890205', 'BU04890206', 'BU04890207', 'BU04890308', 'BU04890409', 'BU04890410', 'BU04890511', 'BU04890512', 'BU04890513', 'BU04890614', 'BU04890715', 'BU04890816', 'BU04890817', 'BU04890918', 'BU04890919', 'BU04890920', 'BU04890921', 'BU04890922', 'BU04891023', 'BU04891124', 'BU04891225', 'BU04891226', 'BU04891227', 'BU04891328', 'BU04891429', 'BU04891430', 'BU04891431', 'BU04891432', 'BU04891533', 'BU04891634', 'BU04891735', 'BU04891836', 'BU04891937', 'BU04892039', 'BU04893050', 'BU04893051', 'BU04893052', 'BU04893053', 'BU04893054', 'BU04893160', 'BU04893161', 'BU04893162', 'BU04893163', 'BU04893164', 'BU04895070', 'BU04895071', 'BU04895072', 'BU04895073', 'BU04895074', 'BU04895075', 'BU04895076', 'BU04895077', 'BU04895078', 'BU04895080', 'BU04895081', 'BU04895082', 'BU04895083', 'BU04895084', 'BU05020110', 'BU05020111', 'BU05020112', 'BU05020113', 'BU05020114', 'BU05020115', 'BU05020116', 'BU05020117', 'BU05020118', 'BU05020119', 'BU05020223', 'BU05020224', 'BU05020225', 'BU05020226', 'BU05020227', 'BU05020228', 'BU05020229', 'BU05020332', 'BU05020333', 'BU05020334', 'BU05020335', 'BU05020336', 'BU05020337', 'BU05020338', 'BU05020441', 'BU05020442', 'BU05020443', 'BU05020444', 'BU05020445', 'BU05020446', 'BU05020447', 'BU05020448', 'BU05020449', 'BU05020551', 'BU05020552', 'BU05020553', 'BU05020554', 'BU05020555', 'BU05020556', 'BU05020557', 'BU05020621', 'BU05020622', 'BU05020631', 'BU05020658', 'BU05020659', 'BU05020661', 'BU05020662', 'BU05020663', 'BU05020664', 'BU05020665', 'BU05020666', 'BU05020770', 'BU05020771', 'BU05020772', 'BU05020773', 'BU05020774', 'BU05020775', 'BU05020776', 'BU05020777', 'BU05020778', 'BU05020779', 'BU05020880', 'BU05020881', 'BU05020882', 'BU05020883', 'BU05020884', 'BU05020885', 'BU05020886', 'BU05020887', 'BU05020888', 'BU05020889', 'BU05020991', 'BU05020992', 'BU05020993', 'BU05020994', 'BU05020995', 'BU05020996', 'BU05020997', 'BU05020998', 'BU05420000', 'BU05420001', 'BU05420002', 'BU05420003', 'BU05420004', 'BU05420005', 'BU05560101', 'BU05560201', 'BU05560202', 'BU05560203', 'BU05560301', 'BU05560302', 'BU05560303', 'BU05560401', 'BU05560402', 'BU05560403', 'BU05560404', 'BU05560405', 'BU05560501', 'BU05560502', 'BU05560601', 'BU05560602', 'BU05560701', 'BU05560702', 'BU05560801', 'BU05970100', 'BU05970200', 'BU05970300', 'BU05970400', 'BU05970500', 'BU05970600', 'BU05970700', 'BU05970800', 'BU05970900', 'BU05971000', 'BU05971100', 'BU05971200', 'BU06130101', 'BU06130102', 'BU06130103', 'BU06130104', 'BU06130205', 'BU06130207', 'BU06130308', 'BU06130309', 'BU06130310', 'BU06130311', 'BU06130312', 'BU06130313', 'BU06130414', 'BU06130415', 'BU06130416', 'BU06130417', 'BU06130418', 'BU06130419', 'BU06130420', 'BU06130521', 'BU06130522', 'BU06130623', 'BU06130624', 'BU06130625', 'BU06130626', 'BU06130706', 'BU06220101', 'BU06220102', 'BU06220103', 'BU06220104', 'BU06220201', 'BU06220202', 'BU06220203', 'BU06220204', 'BU06220205', 'BU06220301', 'BU06220302', 'BU06220303', 'BU06220304', 'BU06220305', 'BU06220306', 'BU06220307', 'BU06220401', 'BU06220402', 'BU06220403', 'BU06220404', 'BU06220501', 'BU06220502', 'BU06220503', 'BU06220504', 'BU06220505', 'BU06220601', 'BU06220602', 'BU06220603', 'BU06220604', 'BU06220605', 'BU06220606', 'BU06220701', 'BU06220702', 'BU06220703', 'BU06220704', 'BU06220705', 'BU06220706', 'BU06220707', 'BU06220708', 'BU06220801', 'BU16211111', 'BU16211121', 'BU16211211', 'BU16211221', 'BU16211231', 'BU16211311', 'BU16211321', 'BU16211331', 'BU16211411', 'BU16211514', 'BU16211522', 'BU16211531', 'BU16211543', 'BU16211552', 'BU16212111', 'BU16212121', 'BU16212131', 'BU16212144', 'BU16212211', 'BU16212221', 'BU16212231', 'BU16212241', 'BU16212254', 'BU16212311', 'BU16212321', 'BU16212331', 'BU16212412', 'BU16212511', 'BU16212521', 'BU16212531', 'BU16212541', 'BU16212611', 'BU16212621', 'BU16212633', 'BU16212644', 'BU16212711', 'BU16212721', 'BU16212731', 'BU16212741', 'BU16212814', 'BU16212823', 'BU162128 ...

# %%
rotterdam_adj_2023 = adj_2023.loc[buurten_rotterdam, buurten_rotterdam]
rotterdam_adj_2023
# Out:
#             BU04890101  BU04890102  ...  BU06061101  BU06061102
# BU04890101         0.0         1.0  ...         0.0         0.0
# BU04890102         1.0         0.0  ...         0.0         0.0
# BU04890103         1.0         0.0  ...         0.0         0.0
# BU04890204         1.0         0.0  ...         0.0         0.0
# BU04890205         0.0         0.0  ...         0.0         0.0
# ...                ...         ...  ...         ...         ...
# BU06061005         0.0         0.0  ...         1.0         1.0
# BU06061006         0.0         0.0  ...         0.0         1.0
# BU06061007         0.0         0.0  ...         0.0         1.0
# BU06061101         0.0         0.0  ...         0.0         1.0
# BU06061102         0.0         0.0  ...         1.0         0.0
#
# [625 rows x 625 columns]

# %%
rotterdam_adj_2023.to_csv("../../housing-data/rotterdam_adj_2023.csv")

# %%
df_combined.drop(["PROVINCIECODE","COROPPLUSCODE","GEMEENTECODE"],axis=1, inplace=True)
df_rotterdam.drop(["PROVINCIECODE","COROPPLUSCODE","GEMEENTECODE"],axis=1, inplace=True)
# Out:
# C:\Users\AratrikaD\AppData\Local\Temp\ipykernel_17872\1967209208.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rotterdam.drop(["PROVINCIECODE","COROPPLUSCODE","GEMEENTECODE"],axis=1, inplace=True)

# %%
df_combined.to_csv("../../housing-data/transaction_data.csv", index=False)

df_rotterdam.to_csv("../../housing-data/rotterdam_transaction_data.csv", index=False)

# %% [markdown]
# Encoding buurten for rotterdam

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
transactions_rot = pd.read_csv("../../housing-data/rotterdam_transaction_data.csv")
features_rot = pd.read_csv("../../housing-data/all_neighborhood_features_rotterdam.csv")
adj_rot = pd.read_csv("../../housing-data/rotterdam_adj_2023.csv", index_col=0)

# %%
buurten = adj_rot.columns.values
label_encoder = LabelEncoder()
label_encoder.fit(buurten)

transactions_rot["BUURTCODE"] = label_encoder.transform(transactions_rot["BUURTCODE"])
features_rot["BUURTCODE"] = label_encoder.transform(features_rot["BUURTCODE"])

features_rot
# Out:
#       BUURTCODE  YEAR  ...  MATEVANSTEDELIJKHEID  OMGEVINGSADRESSENDICHTHEID
# 0             0  2014  ...              1.999999                 2086.999342
# 1             1  2014  ...              1.954893                 1982.046788
# 2             2  2014  ...              1.999999                 1891.999490
# 3             3  2014  ...              1.999999                 1676.999580
# 4             4  2014  ...              1.999999                 1578.999485
# ...         ...   ...  ...                   ...                         ...
# 6870        620  2024  ...              5.000000                  281.000000
# 6871        621  2024  ...              5.000000                  284.000000
# 6872        622  2024  ...              5.000000                  278.000000
# 6873        623  2024  ...              5.000000                   95.000000
# 6874        624  2024  ...              5.000000                   84.000000
#
# [6875 rows x 204 columns]

# %%
transactions_rot
# Out:
#         TRANSID       DATUM  ...  FOTOWIJZER_TYPE  LOG_KOOPSOM
# 0       7537440  2021-11-29  ...                6    12.608199
# 1       7308578  2021-09-10  ...                2    13.270783
# 2       4689877  2016-06-15  ...                6    12.301383
# 3       5421309  2019-02-01  ...                1    13.011432
# 4       6215385  2020-10-29  ...                6    12.528156
# ...         ...         ...  ...              ...          ...
# 108994  5490122  2019-05-08  ...                9    12.107357
# 108995  5022491  2017-08-31  ...                1    13.226904
# 108996  5014000  2017-08-01  ...                4    12.122691
# 108997  4641789  2016-03-02  ...                2    12.100712
# 108998  5070150  2017-10-23  ...               14    11.790557
#
# [108999 rows x 16 columns]

# %%
transactions_rot.to_csv("../../housing-data/rotterdam_transaction_data.csv", index=False)
features_rot.to_csv("../../housing-data/all_neighborhood_features_rotterdam.csv", index=False)

# %% [markdown]
# Encode BUURTCODE for all transaction data

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
transactions_rot = pd.read_csv("../../housing-data/transaction_data.csv")
features_rot = pd.read_csv("../../housing-data/all_neighborhood_features.csv")
adj_rot = pd.read_csv("../../housing-data/buurt_adj_2023.csv", index_col=0)

# %%
buurten = adj_rot.columns.values
label_encoder = LabelEncoder()
label_encoder.fit(buurten)

transactions_rot["BUURTCODE"] = label_encoder.transform(transactions_rot["BUURTCODE"])
features_rot["BUURTCODE"] = label_encoder.transform(features_rot["BUURTCODE"])

features_rot
# Out:
#         BUURTCODE  YEAR  LEEFBAAROMETER     GROEN        EC       NO2  \
# 0               0  2014        3.995231  0.006693  0.000461  0.016060
# 1               1  2014        4.007582  0.008081  0.000455  0.016122
# 2               2  2014        3.641874  0.006982  0.000415  0.014185
# 3               3  2014        0.753490  0.003809  0.000085  0.003003
# 4               4  2014        0.894338  0.005688  0.000090  0.002953
# ...           ...   ...             ...       ...       ...       ...
# 158626      14416  2024        4.042706  0.040761  0.000251  0.017493
# 158627      14417  2024        4.061659  0.047161  0.000250  0.017436
# 158628      14418  2024        4.269247  0.046067  0.000249  0.017399
# 158629      14419  2024        4.166958  0.032288  0.000240  0.017008
# 158630      14420  2024        4.110712  0.056326  0.000243  0.017815
#
#            PM2_5      PM10  GELUIDSHINDERTOTAAL  AFSTANDTOTHUISARTSENPRAKTIJK  \
# 0       0.007822  0.014309             0.298703                      0.284183
# 1       0.007893  0.014397             0.283425                      0.190341
# 2       0.007163  0.013116             0.288608                      0.260024
# 3       0.001451  0.002648             0.059165                      0.085903
# 4       0.001722  0.003162             0.068266                      0.146036
# ...          ...       ...                  ...                           ...
# 158626  0.007697  0.015455             0.327098                      3.400000
# 158627  0.007677  0.015409             0.321582                      3.600000
# 158628  0.007667  0.015397             0.330565                      3.800000
# 158629  0.007543  0.015186             0.315714                      3.592785
# 158630  0.007529  0.015110             0.345281                      4.900000
#
#         ...  MOTORFIETSEN  AFSTANDTOTSCHOOL  SCHOLENBINNEN3KM  \
# 0       ...     49.888193          0.375635         14.757827
# 1       ...    166.508675          0.666068         17.033365
# 2       ...     69.329417          0.691056         13.847204
# 3       ...      6.063573          0.121271          2.891182
# 4       ...     12.225972          0.108682          3.353267
# ...     ...           ...               ...               ...
# 158626  ...     30.000000          0.400000          1.500000
# 158627  ...     60.000000          0.800000          1.000000
# 158628  ...     10.000000          0.500000          1.000000
# 158629  ...     25.000000          2.195591          1.197595
# 158630  ...      0.000000          4.300000          0.000000
#
#         OPPERVLAKTETOTAAL  OPPERVLAKTELAND  OPPERVLAKTEWATER  \
# 0               18.490892        17.547828          0.943063
# 1               58.045759        52.336699          5.709061
# 2               20.233320        18.501707          1.725773
# 3                8.553599         8.039100          0.514499
# 4               14.388711        13.969846          0.418865
# ...                   ...              ...               ...
# 158626          21.000000        20.000000          0.000000
# 158627          30.000000        27.000000          4.000000
# 158628          17.000000        11.000000          6.000000
# 158629         884.000000       809.000000         75.000000
# 158630         233.000000       121.000000        112.000000
#
#         MEESTVOORKOMENDEPOSTCODE  DEKKINGSPERCENTAGE  MATEVANSTEDELIJKHEID  \
# 0                    9154.228572            0.942569              0.942569
# 1                    9241.205004            0.951622              0.951622
# 2                    8415.392590            0.866582              0.866582
# 3                    1696.287864            0.174554              0.174554
# 4                    2090.053623            0.215098              0.215098
# ...                          ...                 ...                   ...
# 158626               3238.000000            1.000000              5.000000
# 158627               3238.000000            3.000000              5.000000
# 158628               3238.000000            1.000000              5.000000
# 158629               3238.000000            1.000000              5.000000
# 158630               3231.000000            1.000000              5.000000
#
#         OMGEVINGSADRESSENDICHTHEID
# 0                      5887.160036
# 1                      5664.661950
# 2                      4884.304548
# 3                       943.576910
# 4                      1141.582224
# ...                            ...
# 158626                  281.000000
# 158627                  284.000000
# 158628                  278.000000
# 158629                   95.000000
# 158630                   84.000000
#
# [158631 rows x 204 columns]

# %%
features_rot[features_rot["BUURTCODE"] == 1]
# Out:
#         BUURTCODE  YEAR  LEEFBAAROMETER     GROEN        EC       NO2  \
# 1               1  2014        4.007582  0.008081  0.000455  0.016122
# 14422           1  2015        4.035009  0.008133  0.000459  0.016232
# 28843           1  2016        4.078002  0.008099  0.000456  0.016157
# 43264           1  2017        4.096730  0.008147  0.000459  0.016232
# 57685           1  2018        4.049475  0.008089  0.000456  0.016157
# 72106           1  2019        4.049475  0.008120  0.000456  0.016155
# 86527           1  2020        4.073560  0.008121  0.000329  0.013180
# 100948          1  2021        4.073560  0.008118  0.000329  0.013179
# 115369          1  2022        4.075480  0.008109  0.000217  0.012210
# 129790          1  2023        4.272947  0.008485  0.000228  0.012802
# 144211          1  2024        4.272947  0.008485  0.000228  0.012802
#
#            PM2_5      PM10  GELUIDSHINDERTOTAAL  AFSTANDTOTHUISARTSENPRAKTIJK  \
# 1       0.007893  0.014397             0.283425                      0.190341
# 14422   0.007947  0.014495             0.285366                      0.287440
# 28843   0.007910  0.014428             0.284083                      0.191088
# 43264   0.007947  0.014495             0.285394                      0.287554
# 57685   0.007910  0.014428             0.283997                      0.286295
# 72106   0.007910  0.014427             0.284082                      0.286295
# 86527   0.006780  0.013309             0.284079                      0.286295
# 100948  0.006780  0.013309             0.284096                      0.286295
# 115369  0.007187  0.014209             0.284047                      0.286295
# 129790  0.007535  0.014897             0.297746                      0.300000
# 144211  0.007535  0.014897             0.297746                      0.300000
#
#         ...  MOTORFIETSEN  AFSTANDTOTSCHOOL  SCHOLENBINNEN3KM  \
# 1       ...    166.508675          0.666068         17.033365
# 14422   ...    167.565383          0.670352         17.148205
# 28843   ...    171.506978          0.667121         16.973428
# 43264   ...    181.914650          0.670352         17.052506
# 57685   ...    166.747303          0.667124         16.973158
# 72106   ...    104.828960          0.667124         16.973327
# 86527   ...     95.299820          0.667124         16.878288
# 100948  ...    104.803684          0.666956         16.496954
# 115369  ...     90.547889          0.666956         16.496954
# 129790  ...    110.000000          0.700000         17.300000
# 144211  ...    110.000000          0.700000         17.300000
#
#         OPPERVLAKTETOTAAL  OPPERVLAKTELAND  OPPERVLAKTEWATER  \
# 1               58.045759        52.336699          5.709061
# 14422           56.507148        52.676887          3.830261
# 28843           56.237708        52.426067          3.811641
# 43264           56.507148        52.676887          3.830261
# 57685           56.237931        52.426275          3.811656
# 72106           56.237931        52.426275          3.811656
# 86527           56.237931        52.426275          3.811656
# 100948          56.237931        52.426275          3.811656
# 115369          56.237931        52.426275          3.811656
# 129790          59.000000        55.000000          4.000000
# 144211          59.000000        55.000000          4.000000
#
#         MEESTVOORKOMENDEPOSTCODE  DEKKINGSPERCENTAGE  MATEVANSTEDELIJKHEID  \
# 1                    9241.205004            0.951622              0.951622
# 14422                9304.437302            0.958134              0.958134
# 28843                9261.894134            0.953753              0.953753
# 43264                9304.437302            0.958134              0.958134
# 57685                9261.930844            0.953756              0.953756
# 72106                9261.930844            0.953756              0.953756
# 86527                9261.930930            0.953756              0.953756
# 100948               9261.930930            0.953756              0.953756
# 115369               9261.930930            0.953756              0.953756
# 129790               9711.000000            1.000000              1.000000
# 144211               9711.000000            1.000000              1.000000
#
#         OMGEVINGSADRESSENDICHTHEID
# 1                      5664.661950
# 14422                  5502.864153
# 28843                  5574.211013
# 43264                  5720.390059
# 57685                  5695.355118
# 72106                  5806.006035
# 86527                  5901.371630
# 100948                 5971.022815
# 115369                 6120.752473
# 129790                 6586.000000
# 144211                 6586.000000
#
# [11 rows x 204 columns]

# %%
transactions_rot
# Out:
#          TRANSID       DATUM  WONINGTYPE   SOC  CALCOPP  KAVOPP  BOUWJAAR  \
# 0        8324024  2023-03-13         3.0  1131      124     119      1976
# 1        4695633  2016-06-01         3.0  1131      145     208      2000
# 2        6267016  2020-11-16         3.0  1131      140     130      2014
# 3        6428993  2021-02-01         3.0  1136      261     162      1912
# 4        5382171  2018-12-04         0.0  1181       50       0      1974
# ...          ...         ...         ...   ...      ...     ...       ...
# 1606347  4527050  2015-09-02         3.0  1131      125     155      1975
# 1606348  8518792  2023-11-27         3.0  1138      123      98      1970
# 1606349  6068581  2020-06-16         0.0  1184       93       0      2001
# 1606350  4943077  2017-05-05         4.0  1111      165     367      1935
# 1606351  5351086  2018-11-30         4.0  1111      152     458      1990
#
#          BUURTCODE        LAT       LON  BESTEMMING  DUMMY_BERGING  \
# 0            13959  51.850627  4.893862         1.0              1
# 1             4785  52.492774  4.660815         1.0              1
# 2             2955  51.875469  5.868624         1.0              1
# 3             6448  52.091945  4.272226         1.0              1
# 4             7828  52.213655  4.862490         1.0              1
# ...            ...        ...       ...         ...            ...
# 1606347       3787  52.167385  5.285358         1.0              1
# 1606348       2583  52.046115  5.638586         1.0              0
# 1606349       3515  52.199698  5.369747         1.0              1
# 1606350      13973  51.940161  4.853196         1.0              1
# 1606351      13024  51.841510  5.995801         1.0              0
#
#          DUMMY_GARAGE  DUMMY_MONUMENT  FOTOWIJZER_TYPE  LOG_KOOPSOM
# 0                   0               0                6    12.842649
# 1                   0               0                6    12.456831
# 2                   0               0                6    12.892950
# 3                   0               0                6    13.910821
# 4                   0               0                9    12.100712
# ...               ...             ...              ...          ...
# 1606347             0               0                6    12.185870
# 1606348             1               0                6    12.791181
# 1606349             0               0               10    12.413087
# 1606350             0               0                1    12.765688
# 1606351             1               0                1    12.660328
#
# [1606352 rows x 16 columns]

# %%
transactions_rot.to_csv("../../housing-data/transaction_data.csv", index=False)
features_rot.to_csv("../../housing-data/all_neighborhood_features.csv", index=False)
